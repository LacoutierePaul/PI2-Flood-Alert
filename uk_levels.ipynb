# %% [markdown]
# # Test API "Flood levels"

# %%
import requests
import json
import pandas as pd
import folium
from folium.plugins import MarkerCluster

# %%
url_measures = "http://environment.data.gov.uk/flood-monitoring/id/measures"

url_stations = "http://environment.data.gov.uk/flood-monitoring/id/stations"

# %% [markdown]
# ### à remplir : le(s) paramètre(s) voulu(s)

# %%
params_measures = {
    "parameter": "level",
}

params_stations = {
}

# %% [markdown]
# ### requêtes

# %%
try:
    api_request = requests.get(url_measures, params=params_measures)
    data_measures = json.loads(api_request.content)
except Exception as e:
    data_measures = "Error..."

try:
    api_request = requests.get(url_stations, params=params_stations)
    data_stations = json.loads(api_request.content)
except Exception as e:
    data_stations = "Error..."

# %% [markdown]
# ### passage à un DataFrame

# %%
df = pd.DataFrame(data_measures["items"])

df.head(10)
# Out:
#                                                  @id
# 0  http://environment.data.gov.uk/flood-monitorin...  \
# 1  http://environment.data.gov.uk/flood-monitorin...
# 2  http://environment.data.gov.uk/flood-monitorin...
# 3  http://environment.data.gov.uk/flood-monitorin...
# 4  http://environment.data.gov.uk/flood-monitorin...
# 5  http://environment.data.gov.uk/flood-monitorin...
# 6  http://environment.data.gov.uk/flood-monitorin...
# 7  http://environment.data.gov.uk/flood-monitorin...
# 8  http://environment.data.gov.uk/flood-monitorin...
# 9  http://environment.data.gov.uk/flood-monitorin...
#
#                                            datumType
# 0  http://environment.data.gov.uk/flood-monitorin...  \
# 1  http://environment.data.gov.uk/flood-monitorin...
# 2  http://environment.data.gov.uk/flood-monitorin...
# 3  http://environment.data.gov.uk/flood-monitorin...
# 4  http://environment.data.gov.uk/flood-monitorin...
# 5  http://environment.data.gov.uk/flood-monitorin...
# 6  http://environment.data.gov.uk/flood-monitorin...
# 7                                                NaN
# 8  http://environment.data.gov.uk/flood-monitorin...
# 9  http://environment.data.gov.uk/flood-monitorin...
#
#                                                label
# 0  RIVER DIKLER AT BOURTON ON THE WATER - level-d...  \
# 1  RIVER DIKLER AT BOURTON ON THE WATER - level-s...
# 2        SURFLEET SLUICE - level-stage-i-15_min-mASD
# 3             GAW BRIDGE - level-stage-i-15_min-mASD
# 4  HEMINGFORD GREY SLUICE - level-stage-i-15_min-...
# 5            Swindon LVL - level-stage-i-15_min-mASD
# 6  PENRYN TRELAWNEY PARK - level-downstage-i-15_m...
# 7                  Brock A6 - level-stage-i-15_min-m
# 8    HATTERELL BRIDGE GS - level-stage-i-15_min-mAOD
# 9    HATTERELL BRIDGE GS - level-stage-i-15_min-mASD
#
#                                        latestReading
# 0  {'@id': 'http://environment.data.gov.uk/flood-...  \
# 1  {'@id': 'http://environment.data.gov.uk/flood-...
# 2  {'@id': 'http://environment.data.gov.uk/flood-...
# 3  {'@id': 'http://environment.data.gov.uk/flood-...
# 4  {'@id': 'http://environment.data.gov.uk/flood-...
# 5  {'@id': 'http://environment.data.gov.uk/flood-...
# 6  {'@id': 'http://environment.data.gov.uk/flood-...
# 7  {'@id': 'http://environment.data.gov.uk/flood-...
# 8                                                NaN
# 9                                                NaN
#
#                                notation parameter parameterName  period
# 0  1029TH-level-downstage-i-15_min-mASD     level   Water Level   900.0  \
# 1      1029TH-level-stage-i-15_min-mASD     level   Water Level   900.0
# 2       E2043-level-stage-i-15_min-mASD     level   Water Level   900.0
# 3       52119-level-stage-i-15_min-mASD     level   Water Level   900.0
# 4      E21136-level-stage-i-15_min-mASD     level   Water Level   900.0
# 5        2067-level-stage-i-15_min-mASD     level   Water Level   900.0
# 6   48143-level-downstage-i-15_min-mASD     level   Water Level   900.0
# 7         720215-level-stage-i-15_min-m     level   Water Level   900.0
# 8       E9250-level-stage-i-15_min-mAOD     level   Water Level   900.0
# 9       E9250-level-stage-i-15_min-mASD     level   Water Level   900.0
#
#           qualifier                                            station
# 0  Downstream Stage  http://environment.data.gov.uk/flood-monitorin...  \
# 1             Stage  http://environment.data.gov.uk/flood-monitorin...
# 2             Stage  http://environment.data.gov.uk/flood-monitorin...
# 3             Stage  http://environment.data.gov.uk/flood-monitorin...
# 4             Stage  http://environment.data.gov.uk/flood-monitorin...
# 5             Stage  http://environment.data.gov.uk/flood-monitorin...
# 6  Downstream Stage  http://environment.data.gov.uk/flood-monitorin...
# 7             Stage  http://environment.data.gov.uk/flood-monitorin...
# 8             Stage  http://environment.data.gov.uk/flood-monitorin...
# 9             Stage  http://environment.data.gov.uk/flood-monitorin...
#
#   stationReference                                  unit unitName
# 0           1029TH  http://qudt.org/1.1/vocab/unit#Meter     mASD  \
# 1           1029TH  http://qudt.org/1.1/vocab/unit#Meter     mASD
# 2            E2043  http://qudt.org/1.1/vocab/unit#Meter     mASD
# 3            52119  http://qudt.org/1.1/vocab/unit#Meter     mASD
# 4           E21136  http://qudt.org/1.1/vocab/unit#Meter     mASD
# 5             2067  http://qudt.org/1.1/vocab/unit#Meter     mASD
# 6            48143  http://qudt.org/1.1/vocab/unit#Meter     mASD
# 7           720215  http://qudt.org/1.1/vocab/unit#Meter        m
# 8            E9250  http://qudt.org/1.1/vocab/unit#Meter     mAOD
# 9            E9250  http://qudt.org/1.1/vocab/unit#Meter     mASD
#
#        valueType
# 0  instantaneous
# 1  instantaneous
# 2  instantaneous
# 3  instantaneous
# 4  instantaneous
# 5  instantaneous
# 6  instantaneous
# 7  instantaneous
# 8  instantaneous
# 9  instantaneous

# %%
# affichage des infos générales
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4914 entries, 0 to 4913
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   @id               4914 non-null   object
#  1   datumType         2747 non-null   object
#  2   label             4914 non-null   object
#  3   latestReading     3933 non-null   object
#  4   notation          4914 non-null   object
#  5   parameter         4914 non-null   object
#  6   parameterName     4914 non-null   object
#  7   period            4913 non-null   float64
#  8   qualifier         4914 non-null   object
#  9   station           4914 non-null   object
#  10  stationReference  4914 non-null   object
#  11  unit              4595 non-null   object
#  12  unitName          4914 non-null   object
#  13  valueType         4914 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 537.6+ KB

# %%
df_stations = pd.DataFrame(data_stations["items"])

df_stations.head(10)
# Out:
#                                                  @id RLOIid
# 0  http://environment.data.gov.uk/flood-monitorin...   7041  \
# 1  http://environment.data.gov.uk/flood-monitorin...   6022
# 2  http://environment.data.gov.uk/flood-monitorin...   3072
# 3  http://environment.data.gov.uk/flood-monitorin...   6177
# 4  http://environment.data.gov.uk/flood-monitorin...   2032
# 5  http://environment.data.gov.uk/flood-monitorin...   3158
# 6  http://environment.data.gov.uk/flood-monitorin...   5022
# 7  http://environment.data.gov.uk/flood-monitorin...    NaN
# 8  http://environment.data.gov.uk/flood-monitorin...   8276
# 9  http://environment.data.gov.uk/flood-monitorin...   1152
#
#                              catchmentName  dateOpened easting
# 0                                Cotswolds  1994-01-01  417990  \
# 1                                  Welland  1992-01-01  528000
# 2  Parrett, Brue and West Somerset Streams  1997-01-01  344383
# 3                   Upper and Bedford Ouse  1996-10-01  529500
# 4             Worcestershire Middle Severn  1976-04-06  386120
# 5               Fal and St Austell Streams  2000-01-28  178065
# 6                            Lune and Wyre  1977-01-01  351210
# 7                                      NaN         NaN  517850
# 8                    Wharfe and Lower Ouse  2001-07-11  398476
# 9                                     Ouse  1981-05-01  533288
#
#                    label        lat      long
# 0        Bourton Dickler  51.874767 -1.740083  \
# 1        Surfleet Sluice  52.845991 -0.100848
# 2             Gaw Bridge  50.976043 -2.793549
# 3             Hemingford  52.323618 -0.101287
# 4                Swindon   52.51274 -2.205945
# 5  Penryn Trelawney Park  50.172659 -5.109416
# 6              A6 Bridge  53.858854 -2.743276
# 7    HATTERELL BRIDGE GS  50.965124 -0.323121
# 8        Netherside Hall  54.080705 -2.024779
# 9               Ardingly  51.038451 -0.100268
#
#                                             measures northing notation
# 0  [{'@id': 'http://environment.data.gov.uk/flood...   219610   1029TH  \
# 1  [{'@id': 'http://environment.data.gov.uk/flood...   329300    E2043
# 2  [{'@id': 'http://environment.data.gov.uk/flood...   119926    52119
# 3  [{'@id': 'http://environment.data.gov.uk/flood...   271200   E21136
# 4  [{'@id': 'http://environment.data.gov.uk/flood...   290560     2067
# 5  [{'@id': 'http://environment.data.gov.uk/flood...    34920    48143
# 6  [{'@id': 'http://environment.data.gov.uk/flood...   440550   720215
# 7  [{'@id': 'http://environment.data.gov.uk/flood...   119750    E9250
# 8  [{'@id': 'http://environment.data.gov.uk/flood...   464978    F1906
# 9  [{'@id': 'http://environment.data.gov.uk/flood...   128283    E8266
#
#           riverName                                         stageScale
# 0      River Dikler  http://environment.data.gov.uk/flood-monitorin...  \
# 1        River Glen  http://environment.data.gov.uk/flood-monitorin...
# 2     River Parrett  http://environment.data.gov.uk/flood-monitorin...
# 3  River Great Ouse  http://environment.data.gov.uk/flood-monitorin...
# 4     Smestow Brook  http://environment.data.gov.uk/flood-monitorin...
# 5      Praze Stream  http://environment.data.gov.uk/flood-monitorin...
# 6       River Brock  http://environment.data.gov.uk/flood-monitorin...
# 7               NaN                                                NaN
# 8      River Wharfe  http://environment.data.gov.uk/flood-monitorin...
# 9        River Ouse  http://environment.data.gov.uk/flood-monitorin...
#
#   stationReference                                             status
# 0           1029TH  http://environment.data.gov.uk/flood-monitorin...  \
# 1            E2043  http://environment.data.gov.uk/flood-monitorin...
# 2            52119  http://environment.data.gov.uk/flood-monitorin...
# 3           E21136  http://environment.data.gov.uk/flood-monitorin...
# 4             2067  http://environment.data.gov.uk/flood-monitorin...
# 5            48143  http://environment.data.gov.uk/flood-monitorin...
# 6           720215  http://environment.data.gov.uk/flood-monitorin...
# 7            E9250                                                NaN
# 8            F1906  http://environment.data.gov.uk/flood-monitorin...
# 9            E8266  http://environment.data.gov.uk/flood-monitorin...
#
#                  town    wiskiID  datumOffset gridReference downstageScale
# 0   Little Rissington     1029TH          NaN           NaN            NaN
# 1   Surfleet Seas End     L31004          2.0           NaN            NaN
# 2  Kingsbury Episcopi  520320_FW         10.0           NaN            NaN
# 3     Hemingford Grey     L33865          6.3  TL 2950 7120            NaN
# 4             Swindon       2067          NaN           NaN            NaN
# 5              Penryn  S19726_FW         13.0           NaN            NaN
# 6          Bilsborrow     720215          NaN           NaN            NaN
# 7                 NaN        NaN          NaN      TQ178197            NaN
# 8     Netherside Hall      F1906          NaN  SD9847664978            NaN
# 9            Ardingly  352835027          NaN  TQ3328828283            NaN

# %%
# affichage des infos générales
df_stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5169 entries, 0 to 5168
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   @id               5169 non-null   object
#  1   RLOIid            2477 non-null   object
#  2   catchmentName     2477 non-null   object
#  3   dateOpened        2477 non-null   object
#  4   easting           4698 non-null   object
#  5   label             5169 non-null   object
#  6   lat               4698 non-null   object
#  7   long              4698 non-null   object
#  8   measures          5157 non-null   object
#  9   northing          4698 non-null   object
#  10  notation          5169 non-null   object
#  11  riverName         2477 non-null   object
#  12  stageScale        2477 non-null   object
#  13  stationReference  5169 non-null   object
#  14  status            2477 non-null   object
#  15  town              2343 non-null   object
#  16  wiskiID           2462 non-null   object
#  17  datumOffset       287 non-null    float64
#  18  gridReference     3756 non-null   object
#  19  downstageScale    87 non-null     object
# dtypes: float64(1), object(19)
# memory usage: 807.8+ KB

# %% [markdown]
# ### colonnes inutiles

# %%
# on enlève les colonnes inutiles
df = df.drop(columns=['datumType', 'label', 'notation', 'parameterName', 'period', 'station', ])

# %%
df.head(10)
# Out:
#                                                  @id
# 0  http://environment.data.gov.uk/flood-monitorin...  \
# 1  http://environment.data.gov.uk/flood-monitorin...
# 2  http://environment.data.gov.uk/flood-monitorin...
# 3  http://environment.data.gov.uk/flood-monitorin...
# 4  http://environment.data.gov.uk/flood-monitorin...
# 5  http://environment.data.gov.uk/flood-monitorin...
# 6  http://environment.data.gov.uk/flood-monitorin...
# 7  http://environment.data.gov.uk/flood-monitorin...
# 8  http://environment.data.gov.uk/flood-monitorin...
# 9  http://environment.data.gov.uk/flood-monitorin...
#
#                                        latestReading parameter
# 0  {'@id': 'http://environment.data.gov.uk/flood-...     level  \
# 1  {'@id': 'http://environment.data.gov.uk/flood-...     level
# 2  {'@id': 'http://environment.data.gov.uk/flood-...     level
# 3  {'@id': 'http://environment.data.gov.uk/flood-...     level
# 4  {'@id': 'http://environment.data.gov.uk/flood-...     level
# 5  {'@id': 'http://environment.data.gov.uk/flood-...     level
# 6  {'@id': 'http://environment.data.gov.uk/flood-...     level
# 7  {'@id': 'http://environment.data.gov.uk/flood-...     level
# 8                                                NaN     level
# 9                                                NaN     level
#
#           qualifier stationReference                                  unit
# 0  Downstream Stage           1029TH  http://qudt.org/1.1/vocab/unit#Meter  \
# 1             Stage           1029TH  http://qudt.org/1.1/vocab/unit#Meter
# 2             Stage            E2043  http://qudt.org/1.1/vocab/unit#Meter
# 3             Stage            52119  http://qudt.org/1.1/vocab/unit#Meter
# 4             Stage           E21136  http://qudt.org/1.1/vocab/unit#Meter
# 5             Stage             2067  http://qudt.org/1.1/vocab/unit#Meter
# 6  Downstream Stage            48143  http://qudt.org/1.1/vocab/unit#Meter
# 7             Stage           720215  http://qudt.org/1.1/vocab/unit#Meter
# 8             Stage            E9250  http://qudt.org/1.1/vocab/unit#Meter
# 9             Stage            E9250  http://qudt.org/1.1/vocab/unit#Meter
#
#   unitName      valueType
# 0     mASD  instantaneous
# 1     mASD  instantaneous
# 2     mASD  instantaneous
# 3     mASD  instantaneous
# 4     mASD  instantaneous
# 5     mASD  instantaneous
# 6     mASD  instantaneous
# 7        m  instantaneous
# 8     mAOD  instantaneous
# 9     mASD  instantaneous

# %%
# on ne garde que les colonnes 'lat', 'long' et 'stationReference'
df_stations = df_stations[['lat', 'long', 'stationReference']]

# %%
df_stations.head(10)
# Out:
#          lat      long stationReference
# 0  51.874767 -1.740083           1029TH
# 1  52.845991 -0.100848            E2043
# 2  50.976043 -2.793549            52119
# 3  52.323618 -0.101287           E21136
# 4   52.51274 -2.205945             2067
# 5  50.172659 -5.109416            48143
# 6  53.858854 -2.743276           720215
# 7  50.965124 -0.323121            E9250
# 8  54.080705 -2.024779            F1906
# 9  51.038451 -0.100268            E8266

# %% [markdown]
# ### ajout des colonnes 'dateTime' et 'value' depuis la colonne 'latestReading'

# %%
# ajout des colonnes 'dateTime' et 'value' à partir de la colonne 'latestReading'
extr = df['latestReading'].apply(pd.Series)

# on enlève les colonnes inutiles
extr.drop(columns=['@id', 'date'], inplace=True)

# on ajoute les colonnes 'dateTime' et 'value' à df
df = pd.concat([df, extr], axis=1)

# on supprime la colonne 'latestReading' et 0
df.drop(columns=['latestReading', 0], inplace=True)

# %%
df.head(10)
# Out:
#                                                  @id parameter
# 0  http://environment.data.gov.uk/flood-monitorin...     level  \
# 1  http://environment.data.gov.uk/flood-monitorin...     level
# 2  http://environment.data.gov.uk/flood-monitorin...     level
# 3  http://environment.data.gov.uk/flood-monitorin...     level
# 4  http://environment.data.gov.uk/flood-monitorin...     level
# 5  http://environment.data.gov.uk/flood-monitorin...     level
# 6  http://environment.data.gov.uk/flood-monitorin...     level
# 7  http://environment.data.gov.uk/flood-monitorin...     level
# 8  http://environment.data.gov.uk/flood-monitorin...     level
# 9  http://environment.data.gov.uk/flood-monitorin...     level
#
#           qualifier stationReference                                  unit
# 0  Downstream Stage           1029TH  http://qudt.org/1.1/vocab/unit#Meter  \
# 1             Stage           1029TH  http://qudt.org/1.1/vocab/unit#Meter
# 2             Stage            E2043  http://qudt.org/1.1/vocab/unit#Meter
# 3             Stage            52119  http://qudt.org/1.1/vocab/unit#Meter
# 4             Stage           E21136  http://qudt.org/1.1/vocab/unit#Meter
# 5             Stage             2067  http://qudt.org/1.1/vocab/unit#Meter
# 6  Downstream Stage            48143  http://qudt.org/1.1/vocab/unit#Meter
# 7             Stage           720215  http://qudt.org/1.1/vocab/unit#Meter
# 8             Stage            E9250  http://qudt.org/1.1/vocab/unit#Meter
# 9             Stage            E9250  http://qudt.org/1.1/vocab/unit#Meter
#
#   unitName      valueType              dateTime
# 0     mASD  instantaneous  2023-11-20T01:30:00Z  \
# 1     mASD  instantaneous  2023-11-20T01:30:00Z
# 2     mASD  instantaneous  2023-11-19T18:30:00Z
# 3     mASD  instantaneous  2023-11-20T01:30:00Z
# 4     mASD  instantaneous  2023-11-19T11:00:00Z
# 5     mASD  instantaneous  2023-11-20T01:30:00Z
# 6     mASD  instantaneous  2023-11-19T16:00:00Z
# 7        m  instantaneous  2023-11-20T01:30:00Z
# 8     mAOD  instantaneous                   NaN
# 9     mASD  instantaneous                   NaN
#
#                                              measure   value
# 0  http://environment.data.gov.uk/flood-monitorin...   0.047
# 1  http://environment.data.gov.uk/flood-monitorin...   0.291
# 2  http://environment.data.gov.uk/flood-monitorin...    0.77
# 3  http://environment.data.gov.uk/flood-monitorin...   0.945
# 4  http://environment.data.gov.uk/flood-monitorin...   0.142
# 5  http://environment.data.gov.uk/flood-monitorin...   1.277
# 6  http://environment.data.gov.uk/flood-monitorin... -12.906
# 7  http://environment.data.gov.uk/flood-monitorin...   0.552
# 8                                                NaN     NaN
# 9                                                NaN     NaN

# %% [markdown]
# ### ajout des colonnes 'lat' et 'long' en fonction de 'stationReference'

# %%
# on fusionne les deux dataframes
df = pd.merge(df, df_stations, on='stationReference')

# %%
df.head(10)
# Out:
#                                                  @id parameter
# 0  http://environment.data.gov.uk/flood-monitorin...     level  \
# 1  http://environment.data.gov.uk/flood-monitorin...     level
# 2  http://environment.data.gov.uk/flood-monitorin...     level
# 3  http://environment.data.gov.uk/flood-monitorin...     level
# 4  http://environment.data.gov.uk/flood-monitorin...     level
# 5  http://environment.data.gov.uk/flood-monitorin...     level
# 6  http://environment.data.gov.uk/flood-monitorin...     level
# 7  http://environment.data.gov.uk/flood-monitorin...     level
# 8  http://environment.data.gov.uk/flood-monitorin...     level
# 9  http://environment.data.gov.uk/flood-monitorin...     level
#
#           qualifier stationReference                                  unit
# 0  Downstream Stage           1029TH  http://qudt.org/1.1/vocab/unit#Meter  \
# 1             Stage           1029TH  http://qudt.org/1.1/vocab/unit#Meter
# 2             Stage            E2043  http://qudt.org/1.1/vocab/unit#Meter
# 3             Stage            52119  http://qudt.org/1.1/vocab/unit#Meter
# 4             Stage           E21136  http://qudt.org/1.1/vocab/unit#Meter
# 5             Stage             2067  http://qudt.org/1.1/vocab/unit#Meter
# 6  Downstream Stage            48143  http://qudt.org/1.1/vocab/unit#Meter
# 7             Stage           720215  http://qudt.org/1.1/vocab/unit#Meter
# 8             Stage            E9250  http://qudt.org/1.1/vocab/unit#Meter
# 9             Stage            E9250  http://qudt.org/1.1/vocab/unit#Meter
#
#   unitName      valueType              dateTime
# 0     mASD  instantaneous  2023-11-20T01:30:00Z  \
# 1     mASD  instantaneous  2023-11-20T01:30:00Z
# 2     mASD  instantaneous  2023-11-19T18:30:00Z
# 3     mASD  instantaneous  2023-11-20T01:30:00Z
# 4     mASD  instantaneous  2023-11-19T11:00:00Z
# 5     mASD  instantaneous  2023-11-20T01:30:00Z
# 6     mASD  instantaneous  2023-11-19T16:00:00Z
# 7        m  instantaneous  2023-11-20T01:30:00Z
# 8     mAOD  instantaneous                   NaN
# 9     mASD  instantaneous                   NaN
#
#                                              measure   value        lat
# 0  http://environment.data.gov.uk/flood-monitorin...   0.047  51.874767  \
# 1  http://environment.data.gov.uk/flood-monitorin...   0.291  51.874767
# 2  http://environment.data.gov.uk/flood-monitorin...    0.77  52.845991
# 3  http://environment.data.gov.uk/flood-monitorin...   0.945  50.976043
# 4  http://environment.data.gov.uk/flood-monitorin...   0.142  52.323618
# 5  http://environment.data.gov.uk/flood-monitorin...   1.277   52.51274
# 6  http://environment.data.gov.uk/flood-monitorin... -12.906  50.172659
# 7  http://environment.data.gov.uk/flood-monitorin...   0.552  53.858854
# 8                                                NaN     NaN  50.965124
# 9                                                NaN     NaN  50.965124
#
#        long
# 0 -1.740083
# 1 -1.740083
# 2 -0.100848
# 3 -2.793549
# 4 -0.101287
# 5 -2.205945
# 6 -5.109416
# 7 -2.743276
# 8 -0.323121
# 9 -0.323121

# %% [markdown]
# ### % de valeurs manquantes

# %%
# pourcentage de valeurs manquantes
df.isnull().sum() / len(df) * 100
# Out:
# @id                  0.000000
# parameter            0.000000
# qualifier            0.000000
# stationReference     0.000000
# unit                 6.566488
# unitName             0.000000
# valueType            0.000000
# dateTime            19.020173
# measure             19.020173
# value               19.020173
# lat                 10.168794
# long                10.168794
# dtype: float64

# %%
# on supprime toutes les lignes avec une valeur manquante dans la colonne 'measure'
df.dropna(subset=['measure'], inplace=True)

# on supprime toutes les lignes avec une valeur manquante dans les colonnes 'lat' et 'long'
df.dropna(subset=['lat', 'long'], inplace=True)

# on supprime toutes les lignes avec des valeurs sous forme de liste dans les colonnes 'lat' et 'long'
df = df[~df['lat'].apply(lambda x: isinstance(x, list))]

# %%
df.head(10)
# Out:
#                                                   @id parameter
# 0   http://environment.data.gov.uk/flood-monitorin...     level  \
# 1   http://environment.data.gov.uk/flood-monitorin...     level
# 2   http://environment.data.gov.uk/flood-monitorin...     level
# 3   http://environment.data.gov.uk/flood-monitorin...     level
# 4   http://environment.data.gov.uk/flood-monitorin...     level
# 5   http://environment.data.gov.uk/flood-monitorin...     level
# 6   http://environment.data.gov.uk/flood-monitorin...     level
# 7   http://environment.data.gov.uk/flood-monitorin...     level
# 10  http://environment.data.gov.uk/flood-monitorin...     level
# 11  http://environment.data.gov.uk/flood-monitorin...     level
#
#            qualifier stationReference                                  unit
# 0   Downstream Stage           1029TH  http://qudt.org/1.1/vocab/unit#Meter  \
# 1              Stage           1029TH  http://qudt.org/1.1/vocab/unit#Meter
# 2              Stage            E2043  http://qudt.org/1.1/vocab/unit#Meter
# 3              Stage            52119  http://qudt.org/1.1/vocab/unit#Meter
# 4              Stage           E21136  http://qudt.org/1.1/vocab/unit#Meter
# 5              Stage             2067  http://qudt.org/1.1/vocab/unit#Meter
# 6   Downstream Stage            48143  http://qudt.org/1.1/vocab/unit#Meter
# 7              Stage           720215  http://qudt.org/1.1/vocab/unit#Meter
# 10             Stage            F1906  http://qudt.org/1.1/vocab/unit#Meter
# 11             Stage            E8266  http://qudt.org/1.1/vocab/unit#Meter
#
#    unitName      valueType              dateTime
# 0      mASD  instantaneous  2023-11-20T01:30:00Z  \
# 1      mASD  instantaneous  2023-11-20T01:30:00Z
# 2      mASD  instantaneous  2023-11-19T18:30:00Z
# 3      mASD  instantaneous  2023-11-20T01:30:00Z
# 4      mASD  instantaneous  2023-11-19T11:00:00Z
# 5      mASD  instantaneous  2023-11-20T01:30:00Z
# 6      mASD  instantaneous  2023-11-19T16:00:00Z
# 7         m  instantaneous  2023-11-20T01:30:00Z
# 10        m  instantaneous  2023-11-20T01:30:00Z
# 11     mASD  instantaneous  2023-11-20T01:00:00Z
#
#                                               measure   value        lat
# 0   http://environment.data.gov.uk/flood-monitorin...   0.047  51.874767  \
# 1   http://environment.data.gov.uk/flood-monitorin...   0.291  51.874767
# 2   http://environment.data.gov.uk/flood-monitorin...    0.77  52.845991
# 3   http://environment.data.gov.uk/flood-monitorin...   0.945  50.976043
# 4   http://environment.data.gov.uk/flood-monitorin...   0.142  52.323618
# 5   http://environment.data.gov.uk/flood-monitorin...   1.277   52.51274
# 6   http://environment.data.gov.uk/flood-monitorin... -12.906  50.172659
# 7   http://environment.data.gov.uk/flood-monitorin...   0.552  53.858854
# 10  http://environment.data.gov.uk/flood-monitorin...   1.699  54.080705
# 11  http://environment.data.gov.uk/flood-monitorin...   0.241  51.038451
#
#         long
# 0  -1.740083
# 1  -1.740083
# 2  -0.100848
# 3  -2.793549
# 4  -0.101287
# 5  -2.205945
# 6  -5.109416
# 7  -2.743276
# 10 -2.024779
# 11 -0.100268

# %% [markdown]
# ### on trie par date

# %%
# trie par 'dateTime' dans l'ordre décroissant
df.sort_values(by=['dateTime'], ascending=False, inplace=True)

# %%
df.head(10)
# Out:
#                                                     @id parameter
# 2819  http://environment.data.gov.uk/flood-monitorin...     level  \
# 2432  http://environment.data.gov.uk/flood-monitorin...     level
# 2796  http://environment.data.gov.uk/flood-monitorin...     level
# 2402  http://environment.data.gov.uk/flood-monitorin...     level
# 4162  http://environment.data.gov.uk/flood-monitorin...     level
# 2818  http://environment.data.gov.uk/flood-monitorin...     level
# 3859  http://environment.data.gov.uk/flood-monitorin...     level
# 4325  http://environment.data.gov.uk/flood-monitorin...     level
# 2509  http://environment.data.gov.uk/flood-monitorin...     level
# 2505  http://environment.data.gov.uk/flood-monitorin...     level
#
#              qualifier stationReference                                  unit
# 2819       Tidal Level     DIFF_TB2_TB1  http://qudt.org/1.1/vocab/unit#Meter  \
# 2432       Tidal Level     DIFF_TB3_TB9  http://qudt.org/1.1/vocab/unit#Meter
# 2796       Tidal Level     DIFF_TB2_TB9  http://qudt.org/1.1/vocab/unit#Meter
# 2402       Tidal Level     DIFF_TB3_TB1  http://qudt.org/1.1/vocab/unit#Meter
# 4162             Stage            51129  http://qudt.org/1.1/vocab/unit#Meter
# 2818             Stage           E12513  http://qudt.org/1.1/vocab/unit#Meter
# 3859             Stage           E13880  http://qudt.org/1.1/vocab/unit#Meter
# 4325  Downstream Stage           0350TH  http://qudt.org/1.1/vocab/unit#Meter
# 2509  Downstream Stage           693555  http://qudt.org/1.1/vocab/unit#Meter
# 2505  Downstream Stage           3004TH  http://qudt.org/1.1/vocab/unit#Meter
#
#      unitName      valueType              dateTime
# 2819        m  instantaneous  2023-11-20T01:40:10Z  \
# 2432        m  instantaneous  2023-11-20T01:40:10Z
# 2796        m  instantaneous  2023-11-20T01:40:10Z
# 2402        m  instantaneous  2023-11-20T01:40:10Z
# 4162        m  instantaneous  2023-11-20T01:35:00Z
# 2818     mAOD  instantaneous  2023-11-20T01:33:01Z
# 3859     mAOD  instantaneous  2023-11-20T01:32:54Z
# 4325     mAOD  instantaneous  2023-11-20T01:30:21Z
# 2509        m  instantaneous  2023-11-20T01:30:00Z
# 2505     mAOD  instantaneous  2023-11-20T01:30:00Z
#
#                                                 measure   value        lat
# 2819  http://environment.data.gov.uk/flood-monitorin...   0.023  51.494354  \
# 2432  http://environment.data.gov.uk/flood-monitorin...   0.237  51.494354
# 2796  http://environment.data.gov.uk/flood-monitorin...   0.309  51.494354
# 2402  http://environment.data.gov.uk/flood-monitorin...   0.049  51.494354
# 4162  http://environment.data.gov.uk/flood-monitorin...   0.295   51.13732
# 2818  http://environment.data.gov.uk/flood-monitorin...  35.762  51.060548
# 3859  http://environment.data.gov.uk/flood-monitorin...  78.337  51.251714
# 4325  http://environment.data.gov.uk/flood-monitorin...   -0.09  51.500306
# 2509  http://environment.data.gov.uk/flood-monitorin...   0.061  53.375882
# 2505  http://environment.data.gov.uk/flood-monitorin...  17.088   51.30878
#
#           long
# 2819  0.026414
# 2432  0.026414
# 2796  0.026414
# 2402  0.026414
# 4162  -3.29251
# 2818 -1.310016
# 3859 -1.396843
# 4325  0.181352
# 2509 -2.538601
# 2505 -0.494918

# %%
# toutes les mesures d'une station
df[df['stationReference'] == '0007']
# Out:
#                                                    @id parameter    qualifier
# 541  http://environment.data.gov.uk/flood-monitorin...     level  Tidal Level  \
#
#     stationReference                                  unit unitName
# 541             0007  http://qudt.org/1.1/vocab/unit#Meter     mAOD  \
#
#          valueType              dateTime
# 541  instantaneous  2023-11-20T01:30:00Z  \
#
#                                                measure  value        lat
# 541  http://environment.data.gov.uk/flood-monitorin... -0.363  51.506753  \
#
#          long
# 541 -0.078706

# %% [markdown]
# ### passage à une carte

# %%
# on crée une carte centrée sur le Royaume-Uni
m = folium.Map(location=[54.5, -3.5], zoom_start=6)

# on ajoute les points des 50 premières lignes
for index, row in df.head(50).iterrows():
    folium.Marker([row['lat'], row['long']], popup=row['value']).add_to(m)

# on affiche la carte
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f738d35b04047c4f51f4488b8f15f03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f738d35b04047c4f51f4488b8f15f03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f738d35b04047c4f51f4488b8f15f03 = L.map(
#                 &quot;map_1f738d35b04047c4f51f4488b8f15f03&quot;,
#                 {
#                     center: [54.5, -3.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_207875def79dd01311ffb1e806c9a5c4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1f738d35b04047c4f51f4488b8f15f03);
#
#
#             var marker_0b9c0ace1c29d2d08e63f5185a3febc9 = L.marker(
#                 [51.494354, 0.026414],
#                 {}
#             ).addTo(map_1f738d35b04047c4f51f4488b8f15f03);
#
#
#         var popup_d264a43d1b627699b3745a7047ac52e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53ef1a32ad235f77bf231fc792514b6a = $(`&lt;div id=&quot;html_53ef1a32ad235f77bf231fc792514b6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.023&lt;/div&gt;`)[0];
#                 popup_d264a43d1b627699b3745a7047ac52e9.setContent(html_53ef1a32ad235f77bf231fc792514b6a);
#
#
#
#         marker_0b9c0ace1c29d2d08e63f5185a3febc9.bindPopup(popup_d264a43d1b627699b3745a7047ac52e9)
#         ;
#
#
#
#
#             var marker_36b5b8ae6cc3830e185efd9e61e4608d = L.marker(
#                 [51.494354, 0.026414],
#                 {}
#             ).addTo(map_1f738d35b04047c4f51f4488b8f15f03);
#
#
#         var popup_5369f0a483cc433e00709dc0b4c30cae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2ffe95dfe265aa46f9a787587f5ef3c = $(`&lt;div id=&quot;html_e2ffe95dfe265aa46f9a787587f5ef3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.237&lt;/div&gt;`)[0];
#                 popup_5369f0a483cc433e00709dc0b4c30cae.setContent(html_e2ffe95dfe265aa46f9a787587f5ef3c);
#
#
#
#         marker_36b5b8ae6cc3830e185efd9e61e4608d.bindPopup(popup_5369f0a483cc433e00709dc0b4c30cae)
#         ;
#
#
#
#
#             var marker_32441118ed43c81e3e3990fdea1edff7 = L.marker(
#                 [51.494354, 0.026414],
#                 {}
#             ).addTo(map_1f738d35b04047c4f51f4488b8f15f03);
#
#
#         var popup_f980e5d1727a7f803c7059f35f8b0323 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e8820e2dfc8924fb91d93481d548c30 = $(`&lt;div id=&quot;html_5e8820e2dfc8924fb91d93481d548c30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.309&lt;/div&gt;`)[0];
#                 popup_f980e5d1727a7f803c7059f35f8b0323.setContent(html_5e8820e2dfc8924fb91d93481d548c30);
#
#
#
#         marker_32441118ed43c81e3e3990fdea1edff7.bindPopup(popup_f980e5d1727a7f803c7059f35f8b0323)
#         ;
#
#
#
#
#             var marker_5e1bc838778f50ab734fbce65ed587b9 = L.marker(
#                 [51.494354, 0.026414],
#                 {}
#             ).addTo(map_1f738d35b04047c4f51f4488b8f15f03);
#
#
#         var popup_cf33c9c14aa7c7f1266456493ccaf5a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a6e811e4e7c7807cdfe9b66d31bde16 = $(`&lt;div id=&quot;html_1a6e811e4e7c7807cdfe9b66d31bde16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.049&lt;/div&gt;`)[0];
#                 popup_cf33c9c14aa7c7f1266456493ccaf5a4.setContent(html_1a6e811e4e7c7807cdfe9b66d31bde16);
#
#
#
#         marker_5e1bc838778f50ab734fbce65ed587b9.bindPopup(popup_cf33c9c14aa7c7f1266456493ccaf5a4)
#         ;
#
#
#
#
#             var marker_cca9f77d8d36c0f8d858f3a84b8f0b07 = L.marker(
#                 [51.13732, -3.29251],
#                 {}
#             ).addTo(map_1f738d35b04047c4f51f4488b8f15f03);
#
#
#         var popup_77fbe467461a9ad32865d2794f1937a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c46fea6493e651f2edde0cacf6352a23 = $(`&lt;div id=&quot;html_c46fea6493e651f2edde0cacf6352a23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.295&lt;/div&gt;`)[0];
#                 popup_77fbe467461a9ad32865d2794f1937a4.setContent(html_c46fea6493e651f2edde0cacf6352a23);
#
#
#
#         marker_cca9f77d8d36c0f8d858f3a84b8f0b07.bindPopup(popup_77fbe467461a9ad32865d2794f1937a4)
#         ;
#
#
#
#
#             var marker_99d95e7db34b38864bc9063c3e92a187 = L.marker(
#                 [51.060548, -1.310016],
#                 {}
#             ).addTo(map_1f738d35b04047c4f51f4488b8f15f

# %% [markdown]
# ### essayons de faire une carte interactive

# %%
# on crée une carte centrée sur le Royaume-Uni
m = folium.Map(location=[54.5, -3.5], zoom_start=6)

# on ajoute les points
marker_cluster = MarkerCluster().add_to(m)

# sur les 50 dernières valeurs
for index, row in df.head(50).iterrows():
    folium.Marker([row['lat'], row['long']], popup=row['value']).add_to(marker_cluster)

# on affiche la carte
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0d94497ddd0fa0801a4e33ddffd92b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0d94497ddd0fa0801a4e33ddffd92b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0d94497ddd0fa0801a4e33ddffd92b2 = L.map(
#                 &quot;map_b0d94497ddd0fa0801a4e33ddffd92b2&quot;,
#                 {
#                     center: [54.5, -3.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2b301dda596cedbab85616c54f3df2a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b0d94497ddd0fa0801a4e33ddffd92b2);
#
#
#             var marker_cluster_1ed0f06dcbb30234c70b4382bd36c3f0 = L.markerClusterGroup(
#                 {}
#             );
#             map_b0d94497ddd0fa0801a4e33ddffd92b2.addLayer(marker_cluster_1ed0f06dcbb30234c70b4382bd36c3f0);
#
#
#             var marker_649489638e9f763969183dddf63d5449 = L.marker(
#                 [51.494354, 0.026414],
#                 {}
#             ).addTo(marker_cluster_1ed0f06dcbb30234c70b4382bd36c3f0);
#
#
#         var popup_5f5560be6e521bb268879c5a835937a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1424d5693c8c7bc928f1a36af8d977e4 = $(`&lt;div id=&quot;html_1424d5693c8c7bc928f1a36af8d977e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.023&lt;/div&gt;`)[0];
#                 popup_5f5560be6e521bb268879c5a835937a3.setContent(html_1424d5693c8c7bc928f1a36af8d977e4);
#
#
#
#         marker_649489638e9f763969183dddf63d5449.bindPopup(popup_5f5560be6e521bb268879c5a835937a3)
#         ;
#
#
#
#
#             var marker_0260f196dbdbeeb32db18f30247eb3c8 = L.marker(
#                 [51.494354, 0.026414],
#                 {}
#             ).addTo(marker_cluster_1ed0f06dcbb30234c70b4382bd36c3f0);
#
#
#         var popup_5cbac8b195a2f7a27829c928ad8fede0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_714ea3a6a1086abb4f280b7d80add365 = $(`&lt;div id=&quot;html_714ea3a6a1086abb4f280b7d80add365&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.237&lt;/div&gt;`)[0];
#                 popup_5cbac8b195a2f7a27829c928ad8fede0.setContent(html_714ea3a6a1086abb4f280b7d80add365);
#
#
#
#         marker_0260f196dbdbeeb32db18f30247eb3c8.bindPopup(popup_5cbac8b195a2f7a27829c928ad8fede0)
#         ;
#
#
#
#
#             var marker_70e261f1c45ef2e1d6bebcec1757a8c1 = L.marker(
#                 [51.494354, 0.026414],
#                 {}
#             ).addTo(marker_cluster_1ed0f06dcbb30234c70b4382bd36c3f0);
#
#
#         var popup_bc6638576796a7925645f40083d0ccef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5da525bec1f10c8eead4a026237e9fea = $(`&lt;div id=&quot;html_5da525bec1f10c8eead4a026237e9fea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.309&lt;/div&gt;`)[0];
#                 popup_bc6638576796a7925645f40083d0ccef.setContent(html_5da525bec1f10c8eead4a026237e9fea);
#
#
#
#         marker_70e261f1c45ef2e1d6bebcec1757a8c1.bindPopup(popup_bc6638576796a7925645f40083d0ccef)
#         ;
#
#
#
#
#             var marker_846d29aa438acd84a9762f5c45876034 = L.marker(
#                 [51.494354, 0.026414],
#                 {}
#             ).addTo(marker_cluster_1ed0f06dcbb30234c70b4382bd36c3f0);
#
#
#         var popup_b8045248c38233cde2adb766790bb72f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_435e6b77a24f6209ada9373765c22382 = $(`&lt;div id=&quot;html_435e6b77a24f6209ada9373765c22382&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.049&lt;/div&gt;`)[0];
#                 popup_b8045248c38233cde2adb766790bb72f.setContent(html_435e6b77a24f6209ada9373765c22382);
#
#
#
#         marker_846d29aa438acd84a9762f5c45876034.bindPopup(popup_b8045248c38233cde2adb766790bb72f)
#         ;
#
#
#
#
#             var marker_b46817425a542400e033c12c64c84abb = L.marker(
#                 [51.13732, -3.29251],
#                 {}
#             ).addTo(marker_cluster_1ed0f06dcbb30234c70b4382bd36c3f0);
#
#
#         var popup_961c

# %% [markdown]
# ### maintenant, une carte interactive avec les données des 3 dernières heures

# %%
# nouveau dataframe avec les données des 3 dernières heures
df_3h = df[df['dateTime'] > '2023-10-30T06:00:00Z']

# on crée une carte centrée sur le Royaume-Uni
m = folium.Map(location=[54.5, -3.5], zoom_start=6)

# on ajoute les points
marker_cluster = MarkerCluster().add_to(m)

for index, row in df_3h.iterrows():
    folium.Marker([row['lat'], row['long']], popup=row['stationReference']).add_to(marker_cluster)

# on affiche la carte
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53ec95d5552c0c1ce78ec9959115b433 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53ec95d5552c0c1ce78ec9959115b433&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53ec95d5552c0c1ce78ec9959115b433 = L.map(
#                 &quot;map_53ec95d5552c0c1ce78ec9959115b433&quot;,
#                 {
#                     center: [54.5, -3.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fbf8757d1d020c43e5a4e873d08a1122 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_53ec95d5552c0c1ce78ec9959115b433);
#
#
#             var marker_cluster_c69ddbb7ffcfb482ca396a4656a3d468 = L.markerClusterGroup(
#                 {}
#             );
#             map_53ec95d5552c0c1ce78ec9959115b433.addLayer(marker_cluster_c69ddbb7ffcfb482ca396a4656a3d468);
#
#
#             var marker_7e5aa759bfbb033e315e5d7aabf5ac60 = L.marker(
#                 [51.494354, 0.026414],
#                 {}
#             ).addTo(marker_cluster_c69ddbb7ffcfb482ca396a4656a3d468);
#
#
#         var popup_2dd75fefb348d92e2a51861fff05a88d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4bf1983a3ced76266bcc46d3c9633c49 = $(`&lt;div id=&quot;html_4bf1983a3ced76266bcc46d3c9633c49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DIFF_TB2_TB1&lt;/div&gt;`)[0];
#                 popup_2dd75fefb348d92e2a51861fff05a88d.setContent(html_4bf1983a3ced76266bcc46d3c9633c49);
#
#
#
#         marker_7e5aa759bfbb033e315e5d7aabf5ac60.bindPopup(popup_2dd75fefb348d92e2a51861fff05a88d)
#         ;
#
#
#
#
#             var marker_a083c8790a91edb5688a3f3f175c4e64 = L.marker(
#                 [51.494354, 0.026414],
#                 {}
#             ).addTo(marker_cluster_c69ddbb7ffcfb482ca396a4656a3d468);
#
#
#         var popup_6534a4bd450960f081c09c9a330cbaed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ea6c22b82736a0a9b620d45765ce8c0 = $(`&lt;div id=&quot;html_1ea6c22b82736a0a9b620d45765ce8c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DIFF_TB3_TB9&lt;/div&gt;`)[0];
#                 popup_6534a4bd450960f081c09c9a330cbaed.setContent(html_1ea6c22b82736a0a9b620d45765ce8c0);
#
#
#
#         marker_a083c8790a91edb5688a3f3f175c4e64.bindPopup(popup_6534a4bd450960f081c09c9a330cbaed)
#         ;
#
#
#
#
#             var marker_ff4835041012681f39466763d116227f = L.marker(
#                 [51.494354, 0.026414],
#                 {}
#             ).addTo(marker_cluster_c69ddbb7ffcfb482ca396a4656a3d468);
#
#
#         var popup_33d1929ed48ad623b631b525dc2b7c6e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b0e2c4ca72772b4cdf1cf0be99c3fe9 = $(`&lt;div id=&quot;html_5b0e2c4ca72772b4cdf1cf0be99c3fe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DIFF_TB2_TB9&lt;/div&gt;`)[0];
#                 popup_33d1929ed48ad623b631b525dc2b7c6e.setContent(html_5b0e2c4ca72772b4cdf1cf0be99c3fe9);
#
#
#
#         marker_ff4835041012681f39466763d116227f.bindPopup(popup_33d1929ed48ad623b631b525dc2b7c6e)
#         ;
#
#
#
#
#             var marker_1af15ccffa7c1e830b18a8fc37c883c2 = L.marker(
#                 [51.494354, 0.026414],
#                 {}
#             ).addTo(marker_cluster_c69ddbb7ffcfb482ca396a4656a3d468);
#
#
#         var popup_273837a027857f1c15619c9326cff084 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c14e4133ee22bf996d9a8ccf301f4d71 = $(`&lt;div id=&quot;html_c14e4133ee22bf996d9a8ccf301f4d71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DIFF_TB3_TB1&lt;/div&gt;`)[0];
#                 popup_273837a027857f1c15619c9326cff084.setContent(html_c14e4133ee22bf996d9a8ccf301f4d71);
#
#
#
#         marker_1af15ccffa7c1e830b18a8fc37c883c2.bindPopup(popup_273837a027857f1c15619c9326cff084)
#         ;
#
#
#
#
#             var marker_014558edb127ba49d84ba3b6e86888f0 = L.marker(
#                 [51.13732, -3.29251],
#                 {}
#             ).addTo(marker_cluster_c69ddbb7ffcfb482ca396a4656a3d468);
